# %%
# Importing all the packages
import pandas as pd
import mysql.connector as sql

# %%
# Importing the Limited data
df_t = sql.connect(host= "localhost", user="root", password="12345", database= "solarDB",auth_plugin='mysql_native_password')
sql_query = "SELECT * FROM solardb.datasets"
df = pd.read_sql(sql_query,df_t)
# Out:
# C:\Users\pavva\AppData\Local\Temp\ipykernel_32004\1198119083.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_query,df_t)

# %%
df
# Out:
#         Unnamed: 0      Time       Ipv         Vpv         Vdc        ia  \
# 0                0  0.000028  1.572327  101.348877  144.140625 -0.135133
# 1                1  0.000128  1.503265  101.458740  143.554688 -0.108277
# 2                2  0.000228  1.492859  101.574707  143.554688 -0.168702
# 3                3  0.000328  1.558136  101.312256  143.261719 -0.135133
# 4                4  0.000428  1.631927  101.141357  143.847656 -0.202271
# ...            ...       ...       ...         ...         ...       ...
# 318711      974399  2.500030  1.412445  101.000977  144.140625  0.428832
# 318712      974400  2.500130  1.420959  101.422119  144.433594  0.455688
# 318713      974401  2.500230  1.409607  101.483154  144.140625  0.448974
# 318714      974402  2.500330  1.410553  101.397705  143.847656  0.469115
# 318715      974403  2.500430  1.408661  101.342773  143.847656  0.462401
#
#               ib        ic          va          vb          vc      Iabc  \
# 0       0.490112 -0.354985   41.744537 -149.872894  109.064585  1.000000
# 1       0.510254 -0.388555   46.831512 -150.716705  105.829976  1.000000
# 2       0.496826 -0.334844   51.074677 -152.018585  102.543132  1.000000
# 3       0.510254 -0.361699   55.848236 -152.585144   98.143260  1.000000
# 4       0.503540 -0.321416   60.055237 -152.609253   94.261729  1.000000
# ...          ...       ...         ...         ...         ...       ...
# 318711 -0.422974 -0.012578 -138.397064  131.634521   12.215169  0.485129
# 318712 -0.429688 -0.026006 -140.699463  128.500366   16.602987  0.485298
# 318713 -0.396118 -0.039434 -142.158051  126.222076   21.677907  0.485298
# 318714 -0.409546 -0.059575 -144.315796  122.509308   27.094371  0.485298
# 318715 -0.382690 -0.079717 -145.714111  120.158691   32.615306  0.485400
#
#                If        Vabc         Vf label
# 0       50.000000    1.000000  50.000000   F0L
# 1       50.000000    1.000000  50.000000   F0L
# 2       50.000000    1.000000  50.000000   F0L
# 3       50.000000    1.000000  50.000000   F0L
# 4       50.000000    1.000000  50.000000   F0L
# ...           ...         ...        ...   ...
# 318711  49.703220  155.950288  50.006079   F7L
# 318712  49.708112  155.947211  50.005700   F7L
# 318713  49.708112  155.947211  50.005700   F7L
# 318714  49.708112  155.947211  50.005700   F7L
# 318715  49.713420  155.946957  50.005321   F7L
#
# [318716 rows x 16 columns]

# %%
df['label'].replace({"F0L": 'NF',"F1L": 'F',"F2L":'F',"F3L": 'F',"F4L": 'F',"F5L": 'F',"F6L": 'F',"F7L": 'F'},inplace=(True))
df['label'].value_counts()
# Out:
# F     175001
# NF    143715
# Name: label, dtype: int64

# %%
# Dropping Unwanted Columns
df = df.drop(df.columns[[0, 1]], axis=1)
df.head()
# Out:
#         Ipv         Vpv         Vdc        ia        ib        ic         va  \
# 0  1.572327  101.348877  144.140625 -0.135133  0.490112 -0.354985  41.744537
# 1  1.503265  101.458740  143.554688 -0.108277  0.510254 -0.388555  46.831512
# 2  1.492859  101.574707  143.554688 -0.168702  0.496826 -0.334844  51.074677
# 3  1.558136  101.312256  143.261719 -0.135133  0.510254 -0.361699  55.848236
# 4  1.631927  101.141357  143.847656 -0.202271  0.503540 -0.321416  60.055237
#
#            vb          vc  Iabc    If  Vabc    Vf label
# 0 -149.872894  109.064585   1.0  50.0   1.0  50.0    NF
# 1 -150.716705  105.829976   1.0  50.0   1.0  50.0    NF
# 2 -152.018585  102.543132   1.0  50.0   1.0  50.0    NF
# 3 -152.585144   98.143260   1.0  50.0   1.0  50.0    NF
# 4 -152.609253   94.261729   1.0  50.0   1.0  50.0    NF

# %%
# Importing the Maximum data
df_t1 = sql.connect(host= "localhost", user="root", password="12345", database= "solarDB",auth_plugin='mysql_native_password')
sql_query1 = "SELECT * FROM solardb.datasets_max1"
df1 = pd.read_sql(sql_query1,df_t1)
# Out:
# C:\Users\pavva\AppData\Local\Temp\ipykernel_32004\1041480887.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql(sql_query1,df_t1)

# %%
df1
# Out:
#                Vpv         Vdc        ia        ib        ic          va  \
# 0       101.348877  144.140625 -0.135133  0.490112 -0.354985   41.744537
# 1       101.458740  143.554688 -0.108277  0.510254 -0.388555   46.831512
# 2       101.574707  143.554688 -0.168702  0.496826 -0.334844   51.074677
# 3       101.312256  143.261719 -0.135133  0.510254 -0.361699   55.848236
# 4       101.141357  143.847656 -0.202271  0.503540 -0.321416   60.055237
# ...            ...         ...       ...       ...       ...         ...
# 318710  101.568604  144.433594  0.368407 -0.516968  0.088130 -120.906067
# 318711  101.574707  144.140625  0.368407 -0.483398  0.074702 -123.678589
# 318712  101.440430  144.433594  0.381835 -0.516968  0.047847 -127.162323
# 318713  101.654053  143.847656  0.388549 -0.463257  0.047847 -129.175415
# 318714  101.300049  144.433594  0.408690 -0.490112  0.020991 -132.225189
#
#                 vb          vc      Iabc         If      Vabc         Vf label
# 0      -149.872894  109.064585  1.000000  50.000000    1.0000  50.000000   F0M
# 1      -150.716705  105.829976  1.000000  50.000000    1.0000  50.000000   F0M
# 2      -152.018585  102.543132  1.000000  50.000000    1.0000  50.000000   F0M
# 3      -152.585144   98.143260  1.000000  50.000000    1.0000  50.000000   F0M
# 4      -152.609253   94.261729  1.000000  50.000000    1.0000  50.000000   F0M
# ...            ...         ...       ...        ...       ...        ...   ...
# 318710  146.738739  -22.955678  0.484776  49.694717  155.9473  50.006842   F7M
# 318711  145.135498  -17.884776  0.484776  49.694717  155.9473  50.006842   F7M
# 318712  142.784882  -13.288015  0.484937  49.698753  155.9484  50.006461   F7M
# 318713  140.904388   -8.249257  0.484937  49.698753  155.9484  50.006461   F7M
# 318714  138.505554   -3.435516  0.484937  49.698753  155.9484  50.006461   F7M
#
# [318715 rows x 13 columns]

# %%
df1['label'].replace({"F0M": 'NF',"F1M": 'F',"F2M":'F',"F3M": 'F',"F4M": 'F',"F5M": 'F',"F6M": 'F',"F7M": 'F'},inplace=(True))
df1['label'].value_counts()
# Out:
# F     175000
# NF    143715
# Name: label, dtype: int64

# %%
Max_n_Lim = pd.concat([df, df1])

# %%
Max_n_Lim.to_csv(r"C:\Users\pavva\OneDrive\Documents\Solar Panels Project\Max_n_Lim.csv")

# %%
data = pd.read_csv(r"C:\Users\pavva\OneDrive\Documents\Solar Panels Project\Max_n_Lim.csv")
data.head()
# Out:
#         Ipv         Vpv         Vdc        ia        ib        ic         va  \
# 0  1.572327  101.348877  144.140625 -0.135133  0.490112 -0.354985  41.744537
# 1  1.503265  101.458740  143.554688 -0.108277  0.510254 -0.388555  46.831512
# 2  1.492859  101.574707  143.554688 -0.168702  0.496826 -0.334844  51.074677
# 3  1.558136  101.312256  143.261719 -0.135133  0.510254 -0.361699  55.848236
# 4  1.631927  101.141357  143.847656 -0.202271  0.503540 -0.321416  60.055237
#
#            vb          vc  Iabc    If  Vabc    Vf label
# 0 -149.872894  109.064585   1.0  50.0   1.0  50.0    NF
# 1 -150.716705  105.829976   1.0  50.0   1.0  50.0    NF
# 2 -152.018585  102.543132   1.0  50.0   1.0  50.0    NF
# 3 -152.585144   98.143260   1.0  50.0   1.0  50.0    NF
# 4 -152.609253   94.261729   1.0  50.0   1.0  50.0    NF

# %%
pip install mlbox
# Out:
# Collecting mlbox
#   Downloading mlbox-0.8.5.tar.gz (31 kB)
# Collecting numpy==1.18.2
#   Downloading numpy-1.18.2.zip (5.4 MB)
#   Installing build dependencies: startedNote: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\pavva\anaconda3\python.exe' 'C:\Users\pavva\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\pavva\AppData\Local\Temp\tmpjgju1ruf'
#          cwd: C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\numpy_8af32bf4400145a5a77dca67d097d3c2
#     Complete output (198 lines):
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
# Collecting mlbox
#   Downloading mlbox-0.8.4.tar.gz (31 kB)
#   Downloading mlbox-0.8.3.tar.gz (31 kB)
# Collecting numpy==1.17.0
#   Downloading numpy-1.17.0.zip (6.5 MB)
# Collecting scipy==1.3.0
#   Downloading scipy-1.3.0.tar.gz (23.6 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting mlbox
#   Downloading mlbox-0.8.2.tar.gz (30 kB)
#   Downloading mlbox-0.8.1.tar.gz (31 kB)
#   Downloading mlbox-0.8.0.tar.gz (31 kB)
# Collecting numpy==1.16.3
#   Downloading numpy-1.16.3.zip (5.1 MB)
# Collecting scipy==1.2.1
#   Downloading scipy-1.2.1.tar.gz (23.1 MB)
# Collecting matplotlib==2.2.4
#   Downloading matplotlib-2.2.4.tar.gz (37.0 MB)
# Collecting hyperopt==0.1
#   Downloading hyperopt-0.1.tar.gz (98 kB)
# Collecting Keras==2.1.2
#   Downloading Keras-2.1.2-py2.py3-none-any.whl (304 kB)
# Collecting pandas==0.21.0
#   Downloading pandas-0.21.0.tar.gz (11.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting mlbox
#   Downloading mlbox-0.7.0.tar.gz (31 kB)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (1.21.5)
#   Downloading mlbox-0.6.2.tar.gz (32 kB)
#     Running from numpy source directory.
#     <string>:461: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#     C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\numpy_8af32bf4400145a5a77dca67d097d3c2\tools\cythonize.py:75: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       required_version = LooseVersion('0.29.14')
#     C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\numpy_8af32bf4400145a5a77dca67d097d3c2\tools\cythonize.py:77: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       if LooseVersion(cython_version) < required_version:
#     Processing numpy/random\_bounded_integers.pxd.in
#     Processing numpy/random\mtrand.pyx
#     Processing numpy/random\_bit_generator.pyx
#     Processing numpy/random\_bounded_integers.pyx.in
#     Processing numpy/random\_common.pyx
#     Processing numpy/random\_generator.pyx
#     Processing numpy/random\_mt19937.pyx
#     Processing numpy/random\_pcg64.pyx
#     Processing numpy/random\_philox.pyx
#     Processing numpy/random\_sfc64.pyx
#     Cythonizing sources
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#       libraries blis not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
# Requirement already satisfied: matplotlib>=2.0.2 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (3.5.1)
#   Downloading mlbox-0.6.1.tar.gz (32 kB)
#   Downloading mlbox-0.5.3.tar.gz (32 kB)
# Collecting numpy==1.13.0
#   Downloading numpy-1.13.0.zip (5.0 MB)
# Collecting matplotlib==2.0.2
#   Downloading matplotlib-2.0.2.tar.gz (53.9 MB)
# Collecting mlbox
#   Downloading mlbox-0.5.2.tar.gz (32 kB)
#   Downloading mlbox-0.5.1.tar.gz (31 kB)
# Collecting hyperopt>=0.1
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: Keras>=2.0.4 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (2.8.0)
# Requirement already satisfied: pandas>=0.18.0 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (1.5.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.19b2 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (1.1.3)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (1.10.0)
# Collecting Theano>=0.9.0
#   Downloading Theano-1.0.5.tar.gz (2.8 MB)
# Requirement already satisfied: xgboost>=0.6a2 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (1.7.3)
# Requirement already satisfied: lightgbm>=2.0.2 in c:\users\pavva\anaconda3\lib\site-packages (from mlbox) (3.3.5)
# Requirement already satisfied: six in c:\users\pavva\anaconda3\lib\site-packages (from hyperopt>=0.1->mlbox) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\pavva\anaconda3\lib\site-packages (from hyperopt>=0.1->mlbox) (2.5.1)
# Requirement already satisfied: cloudpickle in c:\users\pavva\anaconda3\lib\site-packages (from hyperopt>=0.1->mlbox) (2.0.0)
# Requirement already satisfied: tqdm in c:\users\pavva\anaconda3\lib\site-packages (from hyperopt>=0.1->mlbox) (4.64.0)
# Requirement already satisfied: future in c:\users\pavva\anaconda3\lib\site-packages (from hyperopt>=0.1->mlbox) (0.18.2)
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: wheel in c:\users\pavva\anaconda3\lib\site-packages (from lightgbm>=2.0.2->mlbox) (0.37.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pavva\anaconda3\lib\site-packages (from matplotlib>=2.0.2->mlbox) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pavva\anaconda3\lib\site-packages (from matplotlib>=2.0.2->mlbox) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\pavva\anaconda3\lib\site-packages (from matplotlib>=2.0.2->mlbox) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pavva\anaconda3\lib\site-packages (from matplotlib>=2.0.2->mlbox) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pavva\anaconda3\lib\site-packages (from matplotlib>=2.0.2->mlbox) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pavva\anaconda3\lib\site-packages (from matplotlib>=2.0.2->mlbox) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\pavva\anaconda3\lib\site-packages (from matplotlib>=2.0.2->mlbox) (23.0)
# Requirement already satisfied: decorator<5,>=4.3 in c:\users\pavva\anaconda3\lib\site-packages (from networkx>=2.2->hyperopt>=0.1->mlbox) (4.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pavva\anaconda3\lib\site-packages (from pandas>=0.18.0->mlbox) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pavva\anaconda3\lib\site-packages (from scikit-learn>=0.19b2->mlbox) (2.2.0)
# Requirement already satisfied: colorama in c:\users\pavva\anaconda3\lib\site-packages (from tqdm->hyperopt>=0.1->mlbox) (0.4.4)
# Building wheels for collected packages: mlbox, Theano
#   Building wheel for mlbox (setup.py): started
#   Building wheel for mlbox (setup.py): still running...
#   Building wheel for mlbox (setup.py): finished with status 'done'
#   Created wheel for mlbox: filename=mlbox-0.5.1-py3-none-any.whl size=47093 sha256=46c47e782b77812824f618069e89596c5cc31e7221a690cdd9809f13145dc31b
#   Stored in directory: c:\users\pavva\appdata\local\pip\cache\wheels\b7\5b\04\4737c4cdbdd0d25c1c0a2be429708675f861e4a9b2baa77908
#   Building wheel for Theano (setup.py): started
#   Building wheel for Theano (setup.py): finished with status 'done'
#   Created wheel for Theano: filename=Theano-1.0.5-py3-none-any.whl size=2668124 sha256=6bfd56a1bd512b9302c8c6d0e2410368a528629eb61c6f9f16292713f3fc6fbd
#   Stored in directory: c:\users\pavva\appdata\local\pip\cache\wheels\12\d8\36\e9b7c617ca8be398dcc48621c539d0cb1d41ff04e4367fc235
# Successfully built mlbox Theano
# Installing collected packages: py4j, Theano, hyperopt, mlbox
# Successfully installed Theano-1.0.5 hyperopt-0.2.7 mlbox-0.5.1 py4j-0.10.9.7
#       NOT AVAILABLE
#
#     openblas_info:
#       libraries openblas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries tatlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#       libraries satlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\numpy_8af32bf4400145a5a77dca67d097d3c2\numpy\distutils\system_info.py:1896: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       if self._calc_info(blas):
#     blas_info:
#       libraries blas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\numpy_8af32bf4400145a5a77dca67d097d3c2\numpy\distutils\system_info.py:1896: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       if self._calc_info(blas):
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\numpy_8af32bf4400145a5a77dca67d097d3c2\numpy\distutils\system_info.py:1896: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       if self._calc_info(blas):
#       NOT AVAILABLE
#
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#       libraries mkl_rt not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#       libraries openblas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#       libraries openblas,lapack not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#       libraries flame not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#       libraries tatlas,tatlas not found in C:\Users\pavva\anaconda3\lib
#       libraries lapack_atlas not found in C:\
#       libraries tatlas,tatlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       libraries tatlas,tatlas not found in C:\Users\pavva\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#       libraries satlas,satlas not found in C:\Users\pavva\anaconda3\lib
#       libraries lapack_atlas not found in C:\
#       libraries satlas,satlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       libraries satlas,satlas not found in C:\Users\pavva\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\pavva\anaconda3\lib
#       libraries lapack_atlas not found in C:\
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\pavva\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#       libraries f77blas,cblas,atlas not found in C:\Users\pavva\anaconda3\lib
#       libraries lapack_atlas not found in C:\
#       libraries f77blas,cblas,atlas not found in C:\
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       libraries f77blas,cblas,atlas not found in C:\Users\pavva\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#       libraries lapack not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\numpy_8af32bf4400145a5a77dca67d097d3c2\numpy\distutils\system_info.py:1730: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\numpy_8af32bf4400145a5a77dca67d097d3c2\numpy\distutils\system_info.py:1730: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-build-env-9bu6qdck\overlay\Lib\site-packages\setuptools\_distutils\dist.py:265: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running dist_info
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/84/1e/ff467ac56bfeaea51d4a2e72d315c1fe440b20192fea7e460f0f248acac8/numpy-1.18.2.zip#sha256=e7894793e6e8540dbeac77c87b489e331947813511108ae097f1715c018b8f3d (from https://pypi.org/simple/numpy/) (requires-python:>=3.5). Command errored out with exit status 1: 'C:\Users\pavva\anaconda3\python.exe' 'C:\Users\pavva\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\pavva\AppData\Local\Temp\tmpjgju1ruf' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\pavva\anaconda3\python.exe' 'C:\Users\pavva\AppData\Local\Temp\pip-standalone-pip-vqoqwnoo\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\pavva\AppData\Local\Temp\pip-build-env-08tx99xn\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- wheel setuptools 'Cython>=0.29.2' 'numpy==1.13.3; python_version=='"'"'3.5'"'"'' 'numpy==1.13.3; python_version=='"'"'3.6'"'"'' 'numpy==1.14.5; python_version>='"'"'3.7'"'"''
#        cwd: None
#   Complete output (579 lines):
#   Ignoring numpy: markers 'python_version == "3.5"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6"' don't match your environment
#   Collecting wheel
#     Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
#   Collecting setuptools
#     Using cached setuptools-67.2.0-py3-none-any.whl (1.1 MB)
#   Collecting Cython>=0.29.2
#     Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
#   Collecting numpy==1.14.5
#     Downloading numpy-1.14.5.zip (4.9 MB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\pavva\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-o2g0h3el\\numpy_74b1468335424cca9d7d4f0d1d0d342b\\setup.py'"'"'; __file__='"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-o2g0h3el\\numpy_74b1468335424cca9d7d4f0d1d0d342b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\pavva\AppData\Local\Temp\pip-wheel-5fyc77zq'
#          cwd: C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\
#     Complete output (264 lines):
#     Running from numpy source directory.
#     C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\misc_util.py:464: SyntaxWarning: "is" with a literal. Did you mean "=="?
#       return is_string(s) and ('*' in s or '?' is s)
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\system_info.py:624: UserWarning:
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         the ATLAS environment variable.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\system_info.py:624: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\system_info.py:624: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     F2PY Version 2
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\pavva\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\pavva\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\pavva\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\pavva\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\pavva\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\pavva\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\pavva\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\pavva\anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\system_info.py:624: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       self.calc_info()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\system_info.py:624: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     C:\Users\pavva\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\pavva\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-o2g0h3el\\numpy_74b1468335424cca9d7d4f0d1d0d342b\\setup.py'"'"'; __file__='"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-o2g0h3el\\numpy_74b1468335424cca9d7d4f0d1d0d342b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#          cwd: C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b
#     Complete output (10 lines):
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     ----------------------------------------
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   Installing collected packages: wheel, setuptools, numpy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'C:\Users\pavva\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-o2g0h3el\\numpy_74b1468335424cca9d7d4f0d1d0d342b\\setup.py'"'"'; __file__='"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-o2g0h3el\\numpy_74b1468335424cca9d7d4f0d1d0d342b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\pavva\AppData\Local\Temp\pip-record-yi0a1lf4\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\pavva\AppData\Local\Temp\pip-build-env-08tx99xn\overlay' --compile --install-headers 'C:\Users\pavva\AppData\Local\Temp\pip-build-env-08tx99xn\overlay\Include\numpy'
#            cwd: C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\
#       Complete output (269 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       blis_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blis not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#       get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       customize GnuFCompiler
#       Could not locate executable g77
#       Could not locate executable f77
#       customize IntelVisualFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifl
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       customize CompaqVisualFCompiler
#       Could not locate executable DF
#       customize IntelItaniumVisualFCompiler
#       Could not locate executable efl
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize G95FCompiler
#       Could not locate executable g95
#       customize IntelEM64VisualFCompiler
#       customize IntelEM64TFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize PGroupFlangCompiler
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\system_info.py:624: UserWarning:
#           Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [atlas]) or by setting
#           the ATLAS environment variable.
#         self.calc_info()
#       blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\system_info.py:624: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\pavva\AppData\Local\Temp\pip-install-o2g0h3el\numpy_74b1468335424cca9d7d4f0d1d0d342b\numpy\distutils\system_info.py:624: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       F2PY Version 2
#       lapack_opt_info:
#       lapack_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_clapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas,lapack not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\Users\pavva\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\Users\pavva\anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\Users\pavva\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\Users\pavva\anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\pavva\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\pavva\anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\Users\pavva\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\Users\pavva\anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
# ...
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#         libraries mkl_rt not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       blis_info:
#         libraries blis not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_info:
#         libraries openblas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries tatlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#         libraries satlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#         libraries f77blas,cblas,atlas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\pavva\AppData\Local\Temp\pip-install-vwvdmf7x\numpy_dfb48fefd3304ae89feddb1903b6b344\numpy\distutils\system_info.py:572: UserWarning:
#           Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [atlas]) or by setting
#           the ATLAS environment variable.
#         self.calc_info()
#       blas_info:
#         libraries blas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\pavva\AppData\Local\Temp\pip-install-vwvdmf7x\numpy_dfb48fefd3304ae89feddb1903b6b344\numpy\distutils\system_info.py:572: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\pavva\AppData\Local\Temp\pip-install-vwvdmf7x\numpy_dfb48fefd3304ae89feddb1903b6b344\numpy\distutils\system_info.py:572: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       F2PY Version 2
#       lapack_opt_info:
#       lapack_mkl_info:
#         libraries mkl_rt not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#         libraries openblas not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries tatlas,tatlas not found in C:\Users\pavva\anaconda3\lib
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#         libraries tatlas,tatlas not found in C:\
#         libraries lapack_atlas not found in C:\
#         libraries tatlas,tatlas not found in C:\Users\pavva\anaconda3\libs
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#         libraries satlas,satlas not found in C:\Users\pavva\anaconda3\lib
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#         libraries satlas,satlas not found in C:\
#         libraries lapack_atlas not found in C:\
#         libraries satlas,satlas not found in C:\Users\pavva\anaconda3\libs
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\pavva\anaconda3\lib
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#         libraries lapack_atlas not found in C:\
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\pavva\anaconda3\libs
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#         libraries f77blas,cblas,atlas not found in C:\Users\pavva\anaconda3\lib
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\lib
#         libraries f77blas,cblas,atlas not found in C:\
#         libraries lapack_atlas not found in C:\
#         libraries f77blas,cblas,atlas not found in C:\Users\pavva\anaconda3\libs
#         libraries lapack_atlas not found in C:\Users\pavva\anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#         libraries lapack not found in ['C:\\Users\\pavva\\anaconda3\\lib', 'C:\\', 'C:\\Users\\pavva\\anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\pavva\AppData\Local\Temp\pip-install-vwvdmf7x\numpy_dfb48fefd3304ae89feddb1903b6b344\numpy\distutils\system_info.py:572: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         self.calc_info()
#       lapack_src_info:
#         NOT AVAILABLE
#
#       C:\Users\pavva\AppData\Local\Temp\pip-install-vwvdmf7x\numpy_dfb48fefd3304ae89feddb1903b6b344\numpy\distutils\system_info.py:572: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       C:\Users\pavva\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       C:\Users\pavva\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'C:\Users\pavva\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-vwvdmf7x\\numpy_dfb48fefd3304ae89feddb1903b6b344\\setup.py'"'"'; __file__='"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-vwvdmf7x\\numpy_dfb48fefd3304ae89feddb1903b6b344\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\pavva\AppData\Local\Temp\pip-record-vmajhv_g\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\pavva\AppData\Local\Temp\pip-build-env-awe7wlcp\overlay' --compile --install-headers 'C:\Users\pavva\AppData\Local\Temp\pip-build-env-awe7wlcp\overlay\Include\numpy' Check the logs for full command output.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/84/4c/622301f99725c6da76ae8079cb6b9091d9098098bd6b4eac47fb502b32f4/pandas-0.21.0.tar.gz#sha256=5cd5cb30e72eeaf202f0e5e180780b897570e889d2db328c689a5a263405c559 (from https://pypi.org/simple/pandas/). Command errored out with exit status 1: 'C:\Users\pavva\anaconda3\python.exe' 'C:\Users\pavva\AppData\Local\Temp\pip-standalone-pip-fjihq0w0\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\pavva\AppData\Local\Temp\pip-build-env-awe7wlcp\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- wheel setuptools Cython 'numpy==1.9.3; python_version=='"'"'3.5'"'"'' 'numpy==1.12.1; python_version=='"'"'3.6'"'"'' 'numpy==1.13.1; python_version>='"'"'3.7'"'"'' Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\pavva\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-6cifqrla\\mlbox_80d5b7b38a7a49be8e0bb20b6f9672dc\\setup.py'"'"'; __file__='"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-6cifqrla\\mlbox_80d5b7b38a7a49be8e0bb20b6f9672dc\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\pavva\AppData\Local\Temp\pip-pip-egg-info-qhn34gq7'
#          cwd: C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\mlbox_80d5b7b38a7a49be8e0bb20b6f9672dc\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\mlbox_80d5b7b38a7a49be8e0bb20b6f9672dc\setup.py", line 10, in <module>
#         with open('requirements.txt', 'rt') as fh:
#     FileNotFoundError: [Errno 2] No such file or directory: 'requirements.txt'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b9/78/eef2c63c63e782454d398a96a296d5c4ae056432f0dd3837d37a5d7e7305/mlbox-0.6.1.tar.gz#sha256=1cdea39dede19ca57ad59e140aab07d0b395dace9187cc8d8b079135749e03b1 (from https://pypi.org/simple/mlbox/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\pavva\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-6cifqrla\\matplotlib_3b71ab6c564b4d489553184375c9420e\\setup.py'"'"'; __file__='"'"'C:\\Users\\pavva\\AppData\\Local\\Temp\\pip-install-6cifqrla\\matplotlib_3b71ab6c564b4d489553184375c9420e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\pavva\AppData\Local\Temp\pip-pip-egg-info-mmi69_u4'
#          cwd: C:\Users\pavva\AppData\Local\Temp\pip-install-6cifqrla\matplotlib_3b71ab6c564b4d489553184375c9420e\
#     Complete output (63 lines):
#     ============================================================================
#     Edit setup.cfg to change the build options
#
#     BUILDING MATPLOTLIB
#                 matplotlib: yes [2.0.2]
#                     python: yes [3.9.12 (main, Apr  4 2022, 05:22:27) [MSC
#                             v.1916 64 bit (AMD64)]]
#                   platform: yes [win32]
#
#     REQUIRED DEPENDENCIES AND EXTENSIONS
#                      numpy: yes [version 1.21.5]
#                        six: yes [using six version 1.16.0]
#                   dateutil: yes [using dateutil version 2.8.2]
#                functools32: yes [Not required]
#               subprocess32: yes [Not required]
#                       pytz: yes [using pytz version 2021.3]
#                     cycler: yes [using cycler version 0.10.0]
#                    tornado: yes [using tornado version 6.1]
#                  pyparsing: yes [using pyparsing version 3.0.4]
#                     libagg: yes [pkg-config information for 'libagg' could not
#                             be found. Using local copy.]
#                   freetype: no  [The C/C++ header for freetype (ft2build.h)
#                             could not be found.  You may need to install the
#                             development package.]
#                        png: no  [The C/C++ header for png (png.h) could not be
#                             found.  You may need to install the development
#                             package.]
#                      qhull: yes [pkg-config information for 'qhull' could not be
#                             found. Using local copy.]
#
#     OPTIONAL SUBPACKAGES
#                sample_data: yes [installing]
#                   toolkits: yes [installing]
#                      tests: no  [skipping due to configuration]
#             toolkits_tests: no  [skipping due to configuration]
#
#     OPTIONAL BACKEND EXTENSIONS
#                     macosx: no  [Mac OS-X only]
#                     qt5agg: yes [installing, Qt: 5.9.7, PyQt: 5.9.7]
#                     qt4agg: no  [PySide not found; PyQt4 not found]
#                    gtk3agg: no  [Requires pygobject to be installed.]
#                  gtk3cairo: no  [Requires cairocffi or pycairo to be installed.]
#                     gtkagg: no  [Requires pygtk]
#                      tkagg: yes [installing; run-time loading from Python Tcl /
#                             Tk]
#                      wxagg: no  [requires wxPython]
#                        gtk: no  [Requires pygtk]
#                        agg: yes [installing]
#                      cairo: no  [cairocffi or pycairo not found]
#                  windowing: yes [installing]
#
#     OPTIONAL LATEX DEPENDENCIES
#                     dvipng: no
#                ghostscript: no
#                      latex: no
#                    pdftops: no
#
#     OPTIONAL PACKAGE DATA
#                       dlls: no  [skipping due to configuration]
#
#     ============================================================================
#                             * The following required packages can not be built:
#                             * freetype, png
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/f5/f0/9da3ef24ea7eb0ccd12430a261b66eca36b924aeef06e17147f9f9d7d310/matplotlib-2.0.2.tar.gz#sha256=0ffbc44faa34a8b1704bc108c451ecf87988f900ef7ce757b8e2e84383121ff1 (from https://pypi.org/simple/matplotlib/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
from mlbox.model_selection import PredictiveModel

mlb = PredictiveModel(verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 from mlbox.model_selection import PredictiveModel
#       3 mlb = PredictiveModel(verbose=True)
#
# File ~\anaconda3\lib\site-packages\mlbox\__init__.py:7, in <module>
#       4 __email__ = 'axelderomblay@gmail.com'
#       5 __version__ = '0.5.1'
# ----> 7 from .preprocessing import *
#       8 from .encoding import *
#       9 from .optimisation import *
#
# File ~\anaconda3\lib\site-packages\mlbox\preprocessing\__init__.py:1, in <module>
# ----> 1 from .drift_thresholder import *
#       2 from .reader import *
#
# File ~\anaconda3\lib\site-packages\mlbox\preprocessing\drift_thresholder.py:9, in <module>
#       7 from sklearn.pipeline import Pipeline
#       8 from .drift import DriftThreshold
# ----> 9 from ..encoding.na_encoder import NA_encoder
#      10 from ..encoding.categorical_encoder import Categorical_encoder
#      13 class Drift_thresholder():
#
# File ~\anaconda3\lib\site-packages\mlbox\encoding\__init__.py:1, in <module>
# ----> 1 from .na_encoder import *
#       2 from .categorical_encoder import *
#
# File ~\anaconda3\lib\site-packages\mlbox\encoding\na_encoder.py:10, in <module>
#       7 import pandas as pd
#       8 import warnings
# ---> 10 from sklearn.preprocessing import Imputer
#      13 class NA_encoder():
#      15     """Encodes missing values for both numerical and categorical features.
#      16
#      17     Several strategies are possible in each case.
#    (...)
#      28         Available strategies = a string or "most_frequent"
#      29     """
#
# ImportError: cannot import name 'Imputer' from 'sklearn.preprocessing' (C:\Users\pavva\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)
